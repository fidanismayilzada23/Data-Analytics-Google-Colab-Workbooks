# %% [markdown]
# <a href="https://colab.research.google.com/github/fidanismayilzada23/Data-Analitc/blob/main/%C4%B0MDBanalis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset haqqında ümumi məlumat

# %%
# pandasi import edin ve imbd datasetini yukleyin
import pandas as pd
df=pd.read_csv('/content/imdbTop250.csv')
df
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# ...

# %%
# Datasetin ilk 10 sətrini ekrana çıxarın.
df.head(10)
# Out:
#    Ranking  IMDByear           IMDBlink                               Title  \
# 0        1      1996  /title/tt0076759/  Star Wars: Episode IV - A New Hope
# 1        2      1996  /title/tt0111161/            The Shawshank Redemption
# 2        3      1996  /title/tt0117951/                       Trainspotting
# 3        4      1996  /title/tt0114814/                  The Usual Suspects
# 4        5      1996  /title/tt0108598/                  The Wrong Trousers
# 5        6      1996  /title/tt0112691/                       A Close Shave
# 6        7      1996  /title/tt0117731/            Star Trek: First Contact
# 7        8      1996  /title/tt0034583/                          Casablanca
# 8        9      1996  /title/tt0083658/                        Blade Runner
# 9       10      1996  /title/tt0108052/                    Schindler's List
#
#    Date  RunTime                       Genre  Rating  Score    Votes   Gross  \
# ...

# %%
# Datasetin sütun adlarını göstərin.
df.columns
# Out:
# Index(['Ranking', 'IMDByear', 'IMDBlink', 'Title', 'Date', 'RunTime', 'Genre',
#        'Rating', 'Score', 'Votes', 'Gross', 'Director', 'Cast1', 'Cast2',
#        'Cast3', 'Cast4'],
#       dtype='object')

# %%
# Datasetdə neçə sətrin və neçə sütunun olduğunu tapın.
print(df.shape[1])
print(df.shape[0])
# Out:
# 16
# 6500

# %%
# Hər bir sütunun data tipini (dtype) göstərən kod yazın.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6500 entries, 0 to 6499
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Ranking   6500 non-null   int64
#  1   IMDByear  6500 non-null   int64
#  2   IMDBlink  6500 non-null   object
#  3   Title     6500 non-null   object
#  4   Date      6500 non-null   int64
#  5   RunTime   6500 non-null   int64
#  6   Genre     6500 non-null   object
#  7   Rating    6500 non-null   float64
#  8   Score     5674 non-null   float64
#  9   Votes     6500 non-null   int64
#  10  Gross     5691 non-null   float64
#  11  Director  6500 non-null   object
#  12  Cast1     6500 non-null   object
#  13  Cast2     6500 non-null   object
#  14  Cast3     6492 non-null   object
#  15  Cast4     6492 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 812.6+ KB

# %%
# Datasetdə ümumilikdə neçə null dəyər olduğunu tapın.
df.isnull().sum().sum()
# Out:
# np.int64(1651)

# %%
# Hər sütundakı null dəyərlərin sayını çıxarın.
df.isnull().sum()
# Out:
# Ranking       0
# IMDByear      0
# IMDBlink      0
# Title         0
# Date          0
# RunTime       0
# Genre         0
# Rating        0
# Score       826
# Votes         0
# Gross       809
# Director      0
# Cast1         0
# Cast2         0
# Cast3         8
# Cast4         8
# dtype: int64

# %%
# Score sütunundakı null dəyərləri median ilə doldurun.
df['Score']=df['Score'].fillna(df['Score'].median())
df
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# ...

# %%
# Gross sutunundaki null deyerleri ortalama ile doldurun
df['Gross']=df['Gross'].fillna(df['Gross'].mean())
df
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# ...

# %%
# Cast3 ve Cast4 sütunlarindakı null dəyərləri əvvəlki sətirdəki dəyərlə (ffill) doldurun.
df[['Cast3','Cast4']]=df[['Cast3','Cast4']].fillna(method='ffill')
# Out:
# /tmp/ipython-input-482058981.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['Cast3','Cast4']]=df[['Cast3','Cast4']].fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# Ranking     0
# IMDByear    0
# IMDBlink    0
# Title       0
# Date        0
# RunTime     0
# Genre       0
# Rating      0
# Score       0
# Votes       0
# Gross       0
# Director    0
# Cast1       0
# Cast2       0
# Cast3       0
# Cast4       0
# dtype: int64

# %% [markdown]
# # Əsas statistik analiz

# %%
# IMDb rating kolonunun maksimum, minimum və orta qiymətlərini tapın.
df['Rating'].max()
# Out:
# 9.3

# %%
df['Rating'].min()
# Out:
# 5.5

# %%
df['Rating'].mean()
# Out:
# np.float64(8.171430769230769)

# %%
# Ən yüksək rating alan filmi tapın (title və rating).    #loc idxmax
df.loc[df['Rating'].idxmax()][['Title','Rating']]
# Out:
# Title     The Shawshank Redemption
# Rating                         9.3
# Name: 1, dtype: object

# %%
# Ən aşağı rating alan filmi tapın.
df.loc[df['Rating'].idxmin()][['Title','Rating']]
# Out:
# Title     Tom and Huck
# Rating             5.5
# Name: 145, dtype: object

# %%
# Date sütununda ən köhnə və ən yeni filmin illerini tapın.
print('En köhne filmin ili:', df['Date'].min())
print('En yeni filmin ili:', df['Date'].max())
# Out:
# En köhne filmin ili: 1920
# En yeni filmin ili: 2021

# %% [markdown]
# # Filtrləmə və seçmə

# %%
# IMDb reytinqi 8.5-dən yüksək olan filmləri seçin.
df[df['Rating']>8.5]
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 9          10      1996   /title/tt0108052/
# 11         12      1996   /title/tt0110912/
# 13         14      1996   /title/tt0068646/
# ...       ...       ...                 ...
# 6279       30      2021   /title/tt0120689/
# 6280       31      2021   /title/tt6751668/
# 6282       33      2021   /title/tt0056058/
# 6389      140      2021  /title/tt15097216/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 9                       Schindler's List  1993      195
# 11                          Pulp Fiction  1994      154
# 13                         The Godfather  1972      175
# ...                                  ...   ...      ...
# ...

# %%
# 2000–2010 illəri arasında çıxmış filmləri siyahıya alın
df[df['Date'].between(2000,2010)]
# Out:
#       Ranking  IMDByear           IMDBlink                           Title  \
# 1050       51      2000  /title/tt0181875/                   Almost Famous
# 1059       60      2000  /title/tt0190332/  Crouching Tiger, Hidden Dragon
# 1076       77      2000  /title/tt0172495/                       Gladiator
# 1137      138      2000  /title/tt0168629/              Dancer in the Dark
# 1149      150      2000  /title/tt0180093/             Requiem for a Dream
# ...       ...       ...                ...                             ...
# 6482      233      2021  /title/tt0118694/            In the Mood for Love
# 6483      234      2021  /title/tt0395169/                    Hotel Rwanda
# 6486      237      2021  /title/tt0758758/                   Into the Wild
# 6488      239      2021  /title/tt0245712/                   Amores perros
# 6491      242      2021  /title/tt0381681/                   Before Sunset
#
# ...

# %%
# Rating-i 9.0–dan yüksək olan ilk 5 filmi seçin.
df[df['Rating']>9.0].head()
# Out:
#      Ranking  IMDByear           IMDBlink                     Title  Date  \
# 1          2      1996  /title/tt0111161/  The Shawshank Redemption  1994
# 13        14      1996  /title/tt0068646/             The Godfather  1972
# 250        1      1997  /title/tt0111161/  The Shawshank Redemption  1994
# 252        3      1997  /title/tt0068646/             The Godfather  1972
# 500        1      1998  /title/tt0111161/  The Shawshank Redemption  1994
#
#      RunTime         Genre  Rating  Score    Votes   Gross  \
# 1        142         Drama     9.3   80.0  2529673   28.34
# 13       175  Crime, Drama     9.2  100.0  1741574  134.97
# 250      142         Drama     9.3   80.0  2529673   28.34
# 252      175  Crime, Drama     9.2  100.0  1741574  134.97
# 500      142         Drama     9.3   80.0  2529673   28.34
#
#                  Director           Cast1             Cast2         Cast3  \
# 1          Frank Darabont     Tim Robbins    Morgan Freeman    Bob Gunton
# ...

# %% [markdown]
# # Qruplaşdırma və sıralama

# %%
# Filmləri il üzrə qruplaşdırın və hər ilin orta IMDb reytinqini hesablayın.
df.groupby('Date')['Rating'].mean()
# Out:
# Date
# 1920    8.100000
# 1921    8.300000
# 1922    7.900000
# 1923    8.100000
# 1924    8.200000
#           ...
# 2017    8.161111
# 2018    8.280000
# 2019    8.275000
# 2020    8.300000
# 2021    8.700000
# Name: Rating, Length: 101, dtype: float64

# %%
# Filmləri IMDb rating-ə görə azalan sırayla düzün.
df.sort_values('Rating', ascending=True)
# Out:
#       Ranking  IMDByear           IMDBlink                          Title  \
# 145       146      1996  /title/tt0112302/                   Tom and Huck
# 144       145      1996  /title/tt0080520/  Cheech and Chong's Next Movie
# 164       165      1996  /title/tt0117333/                     Phenomenon
# 80         81      1996  /title/tt0105946/                      Babylon 5
# 177       178      1996  /title/tt0092610/                      Bad Taste
# ...       ...       ...                ...                            ...
# 5750        1      2019  /title/tt0111161/       The Shawshank Redemption
# 1751        2      2003  /title/tt0111161/       The Shawshank Redemption
# 4500        1      2014  /title/tt0111161/       The Shawshank Redemption
# 3000        1      2008  /title/tt0111161/       The Shawshank Redemption
# 1           2      1996  /title/tt0111161/       The Shawshank Redemption
#
#       Date  RunTime                     Genre  Rating  Score    Votes  \
# ...

# %%
# Rating × votes ilə “IMDB_score_power” adlı yeni sütun yaradın (yüksək reytinq * çox səs = daha güclü film).
df['IMDB_score_power']=df['Rating']*df['Votes']
df
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# ...

# %%
# Datasetdə təkrarlanan sətir (duplicate) olub-olmadığını yoxlayın və varsa silin.
df.drop_duplicates().sum()
# Out:
# Ranking                                                        815750
# IMDByear                                                     13055250
# IMDBlink            /title/tt0076759//title/tt0111161//title/tt011...
# Title               Star Wars: Episode IV - A New HopeThe Shawshan...
# Date                                                         12861221
# RunTime                                                        816422
# Genre               Action, Adventure, FantasyDramaDramaCrime, Dra...
# Rating                                                        53114.3
# Score                                                        548229.0
# Votes                                                      3148275806
# Gross                                                   459612.510104
# Director            George LucasFrank DarabontDanny BoyleBryan Sin...
# Cast1                Mark Hamill Tim Robbins Ewan McGregor Kevin S...
# ...

# %%
# Directora görə qruplaşdırın və hər bir rejissorun neçə film çəkdiyini tapın.
# → Ən çox filmi olan ilk 5 rejissoru göstər.
df.groupby('Director').size().sort_values(ascending=False).head(5)
# Out:
# Director
# Alfred Hitchcock    222
# Stanley Kubrick     199
# Steven Spielberg    154
# Billy Wilder        145
# Martin Scorsese     131
# dtype: int64
